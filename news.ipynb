# %% [markdown]
# ## 네이버 검색 API크롤링

# %%
import os
import urllib.request
import datetime
import json

import pandas as pd
import html
import re
from dotenv import load_dotenv
load_dotenv(verbose=True)

client_id = os.getenv('CLI_ID')
client_secret = os.getenv('CLI_SEC')

# %%
def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
def getNaverSearch(node, srcText, start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)

    url = base + node + parameters
    responseDecode = getRequestUrl(url)

    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

# %%
def getPostData(post, jsonResult, search):
    title = post['title']
    description = post['description']
    link = post['link']
    

    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

    jsonResult.append({'search':search, 'title': title, 'description': description,
                       'link': link, 'pub_date': pDate})

# %%
def clean_text(text):
    text = html.unescape(text)
    text = re.sub(r'<[^>]+>', '', text)
    return text

# %%
node = 'news'
jsonResult = []

# srch1 = input('검색어1: ')
# srch2 = input('검색어2: ')
search_topic = ['AI', '부동산']

for srchText in search_topic:
    jsonResponse = getNaverSearch(node, srchText, 1, 100)    

    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
        for post in jsonResponse['items']:
            getPostData(post, jsonResult, srchText) 

        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srchText, start, 100)


df = pd.DataFrame(jsonResult)
df = df.applymap(lambda x: clean_text(x) if isinstance(x, str) else x)
# Out:
# [2024-05-26 19:25:15.315900] Url Request Success
# [2024-05-26 19:25:15.489890] Url Request Success
# [2024-05-26 19:25:15.719404] Url Request Success
# [2024-05-26 19:25:15.907047] Url Request Success
# [2024-05-26 19:25:16.208110] Url Request Success
# [2024-05-26 19:25:16.468613] Url Request Success
# [2024-05-26 19:25:16.722189] Url Request Success
# [2024-05-26 19:25:16.935109] Url Request Success
# [2024-05-26 19:25:17.149495] Url Request Success
# [2024-05-26 19:25:17.372245] Url Request Success
# HTTP Error 400: Bad Request
# [2024-05-26 19:25:17.480964] Error for URL : https://openapi.naver.com/v1/search/news.json?query=AI&start=1001&display=100
# [2024-05-26 19:25:17.647083] Url Request Success
# [2024-05-26 19:25:17.828498] Url Request Success
# [2024-05-26 19:25:18.052021] Url Request Success
# [2024-05-26 19:25:18.299838] Url Request Success
# [2024-05-26 19:25:18.540240] Url Request Success
# [2024-05-26 19:25:18.742586] Url Request Success
# [2024-05-26 19:25:19.040771] Url Request Success
# [2024-05-26 19:25:19.331391] Url Request Success
# [2024-05-26 19:25:19.574343] Url Request Success
# [2024-05-26 19:25:19.825069] Url Request Success
# HTTP Error 400: Bad Request
# [2024-05-26 19:25:20.025892] Error for URL : https://openapi.naver.com/v1/search/news.json?query=%EB%B6%80%EB%8F%99%EC%82%B0&start=1001&display=100

# %%
nnews_df = df[df['link'].str.contains('https://n.news.naver.com/', na=False)]
nnews_df.reset_index(drop=True, inplace=True)
nnews_df
# Out:
#     search                                    title  \
# 0       AI          초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1       AI                 팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2       AI        고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3       AI                     위기의 삼성 반도체…초격차 변화 예고
# 4       AI   안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# ..     ...                                      ...
# 930    부동산  [올댓차이나] '자금난' 中 완커기업, 협조융자로 3.7조원 자금 조달
# 931    부동산                 “반갑다” 지역 첫 공급 브랜드 아파트 눈길
# 932    부동산       수도권 아파트 '우상향' 시대… '평택 화양 동문 디 이스트'
# 933    부동산                 "너무 비쌌나"…LH, 여의도 부지 또 유찰
# 934    부동산       '글로컬 예비지정' 동신대 겹경사…61억 상당 부동산 기부받아
#
#                                            description  \
# 0    지능 AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있지요. 이제는 웹툰도 ...
# 1    26일 업계에 따르면 겔싱어 CEO는 내달 5일 인텔코리아가 서울에서 진행하는 'A...
# 2    여야가 ‘채 상병 특검법’ 재표결, 연금개혁안 처리 문제 등으로 대치하면서 ‘고준위...
# 3    삼성전자가 인공지능(AI) 반도체의 핵심인 고대역폭메모리(HBM)와 파운드리(반도체...
# 4    인공지능(AI)으로 모두 번역할 수 있으면 이를 기반으로 영화·드라마 등 뛰어난 K...
# ..                                                 ...
# 930  극심한 자금난으로 디폴트(채무불이행) 위기에 직면한 중국 2위 부동산 개발사 완커기...
# 931  24일 한국부동산원 청약홈에 따르면 지난해 12월 경기 부천에서 첫 선을 보인 ‘롯...
# 932  실제로 KB부동산 주택가격동향 자료를 분석한 결과 1999년 통계 공개 이래 수도권...
# 933  평당가도 1억6000만원 수준이라 그에 맞는 수익성이 나는 부동산상품으로 개발하기 ...
# 934  최근 글로컬대학30 사업에 예비지정된 동신대학교가 61억원 상당의 부동산을 기부받았...
#
#                                                   link             pub_date
# 0    https://n.news.naver.com/mnews/article/448/000...  2024-05-26 19:19:00
# 1    https://n.news.naver.com/mnews/article/003/001...  2024-05-26 19:17:00
# 2    https://n.news.naver.com/mnews/article/020/000...  2024-05-26 19:12:00
# 3    https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:11:00
# 4    https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:10:00
# ..                                                 ...                  ...
# 930  https://n.news.naver.com/mnews/article/003/001...  2024-05-24 14:41:00
# 931  https://n.news.naver.com/mnews/article/009/000...  2024-05-24 14:39:00
# 932  https://n.news.naver.com/mnews/article/119/000...  2024-05-24 14:39:00
# 933  https://n.news.naver.com/mnews/article/029/000...  2024-05-24 14:38:00
# 934  https://n.news.naver.com/mnews/article/421/000...  2024-05-24 14:38:00
#
# [935 rows x 5 columns]

# %%
value1_subset = nnews_df[nnews_df['search'] == 'AI'].head(5)
value2_subset = nnews_df[nnews_df['search'] == '부동산'].head(5)

# 두 개의 서브셋을 합침
nnews_df = pd.concat([value1_subset, value2_subset])
nnews_df.reset_index(drop=True, inplace=True)
nnews_df
# Out:
#   search                                           title  \
# 0     AI                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1     AI                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2     AI               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3     AI                            위기의 삼성 반도체…초격차 변화 예고
# 4     AI          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5    부동산                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6    부동산                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7    부동산  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8    부동산         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9    부동산                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                          description  \
# 0  지능 AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있지요. 이제는 웹툰도 ...
# 1  26일 업계에 따르면 겔싱어 CEO는 내달 5일 인텔코리아가 서울에서 진행하는 'A...
# 2  여야가 ‘채 상병 특검법’ 재표결, 연금개혁안 처리 문제 등으로 대치하면서 ‘고준위...
# 3  삼성전자가 인공지능(AI) 반도체의 핵심인 고대역폭메모리(HBM)와 파운드리(반도체...
# 4  인공지능(AI)으로 모두 번역할 수 있으면 이를 기반으로 영화·드라마 등 뛰어난 K...
# 5  버는 것은 없으면서 부동산이나 예금과 주식 같은 금융자산만 많이 가진 자도 부자인가...
# 6  이어 "코로나 팬데믹 기간 주로 시골 지역의 부동산 권리행사를 할 수 없었던 많은 ...
# 7  분당 한솔마을 인근 공인중개사는 "1기 신도시 선도지구 발표에도 이 지역 부동산 분...
# 8  KKR은 부동산 등에 총 4290억달러를 운용하고 있어 자산별, 지역별 시장 상황을...
# 9  다만 '부의 대물림'을 심화시킬 수 있는 부동산 등 일반 자산의 이전에는 칸막이를 ...
#
#                                                 link             pub_date
# 0  https://n.news.naver.com/mnews/article/448/000...  2024-05-26 19:19:00
# 1  https://n.news.naver.com/mnews/article/003/001...  2024-05-26 19:17:00
# 2  https://n.news.naver.com/mnews/article/020/000...  2024-05-26 19:12:00
# 3  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:11:00
# 4  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:10:00
# 5  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:15:00
# 6  https://n.news.naver.com/mnews/article/031/000...  2024-05-26 19:06:00
# 7  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:04:00
# 8  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:02:00
# 9  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:01:00

# %%
nnews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 466
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   search       60 non-null     object
#  1   title        60 non-null     object
#  2   description  60 non-null     object
#  3   link         60 non-null     object
#  4   pub_date     60 non-null     object
# dtypes: object(5)
# memory usage: 2.8+ KB

# %%
nnews_df['link'].iloc[0]
# Out:
# 'https://n.news.naver.com/mnews/article/021/0002639037?sid=102'

# %%
test_df = nnews_df.copy()
test_df
# Out:
#   search                                           title  \
# 0     AI                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1     AI                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2     AI               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3     AI                            위기의 삼성 반도체…초격차 변화 예고
# 4     AI          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5    부동산                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6    부동산                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7    부동산  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8    부동산         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9    부동산                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                          description  \
# 0  지능 AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있지요. 이제는 웹툰도 ...
# 1  26일 업계에 따르면 겔싱어 CEO는 내달 5일 인텔코리아가 서울에서 진행하는 'A...
# 2  여야가 ‘채 상병 특검법’ 재표결, 연금개혁안 처리 문제 등으로 대치하면서 ‘고준위...
# 3  삼성전자가 인공지능(AI) 반도체의 핵심인 고대역폭메모리(HBM)와 파운드리(반도체...
# 4  인공지능(AI)으로 모두 번역할 수 있으면 이를 기반으로 영화·드라마 등 뛰어난 K...
# 5  버는 것은 없으면서 부동산이나 예금과 주식 같은 금융자산만 많이 가진 자도 부자인가...
# 6  이어 "코로나 팬데믹 기간 주로 시골 지역의 부동산 권리행사를 할 수 없었던 많은 ...
# 7  분당 한솔마을 인근 공인중개사는 "1기 신도시 선도지구 발표에도 이 지역 부동산 분...
# 8  KKR은 부동산 등에 총 4290억달러를 운용하고 있어 자산별, 지역별 시장 상황을...
# 9  다만 '부의 대물림'을 심화시킬 수 있는 부동산 등 일반 자산의 이전에는 칸막이를 ...
#
#                                                 link             pub_date
# 0  https://n.news.naver.com/mnews/article/448/000...  2024-05-26 19:19:00
# 1  https://n.news.naver.com/mnews/article/003/001...  2024-05-26 19:17:00
# 2  https://n.news.naver.com/mnews/article/020/000...  2024-05-26 19:12:00
# 3  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:11:00
# 4  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:10:00
# 5  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:15:00
# 6  https://n.news.naver.com/mnews/article/031/000...  2024-05-26 19:06:00
# 7  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:04:00
# 8  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:02:00
# 9  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:01:00

# %% [markdown]
# ## 셀레늄 크롤링

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

import warnings
warnings.filterwarnings(action='ignore')

# %%
def content_crawl(url_path):
    chrome_options = webdriver.ChromeOptions()
    #chrome_options.add_argument('--headless')
    chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(url_path)
    time.sleep(3)
    article_element = driver.find_element(By.XPATH, '//*[@id="dic_area"]')
    content = article_element.text
    return content

# %%
test_df['article'] = test_df['link'].apply(lambda x: content_crawl(x))
test_df
# Out:
#   search                                           title  \
# 0     AI                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1     AI                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2     AI               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3     AI                            위기의 삼성 반도체…초격차 변화 예고
# 4     AI          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5    부동산                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6    부동산                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7    부동산  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8    부동산         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9    부동산                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                          description  \
# 0  지능 AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있지요. 이제는 웹툰도 ...
# 1  26일 업계에 따르면 겔싱어 CEO는 내달 5일 인텔코리아가 서울에서 진행하는 'A...
# 2  여야가 ‘채 상병 특검법’ 재표결, 연금개혁안 처리 문제 등으로 대치하면서 ‘고준위...
# 3  삼성전자가 인공지능(AI) 반도체의 핵심인 고대역폭메모리(HBM)와 파운드리(반도체...
# 4  인공지능(AI)으로 모두 번역할 수 있으면 이를 기반으로 영화·드라마 등 뛰어난 K...
# 5  버는 것은 없으면서 부동산이나 예금과 주식 같은 금융자산만 많이 가진 자도 부자인가...
# 6  이어 "코로나 팬데믹 기간 주로 시골 지역의 부동산 권리행사를 할 수 없었던 많은 ...
# 7  분당 한솔마을 인근 공인중개사는 "1기 신도시 선도지구 발표에도 이 지역 부동산 분...
# 8  KKR은 부동산 등에 총 4290억달러를 운용하고 있어 자산별, 지역별 시장 상황을...
# 9  다만 '부의 대물림'을 심화시킬 수 있는 부동산 등 일반 자산의 이전에는 칸막이를 ...
#
#                                                 link             pub_date  \
# 0  https://n.news.naver.com/mnews/article/448/000...  2024-05-26 19:19:00
# 1  https://n.news.naver.com/mnews/article/003/001...  2024-05-26 19:17:00
# 2  https://n.news.naver.com/mnews/article/020/000...  2024-05-26 19:12:00
# 3  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:11:00
# 4  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:10:00
# 5  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:15:00
# 6  https://n.news.naver.com/mnews/article/031/000...  2024-05-26 19:06:00
# 7  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:04:00
# 8  https://n.news.naver.com/mnews/article/015/000...  2024-05-26 19:02:00
# 9  https://n.news.naver.com/mnews/article/014/000...  2024-05-26 19:01:00
#
#                                              article
# 0  초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI\nTV조선 뉴스\nPlay...
# 1  [서울=뉴시스]인텔 비전 2024에서 팻 겔싱어 인텔 CEO가 인텔 가우디 3 가속...
# 2   ⓒ News1\n21대 국회 임기 만료가 3일 남은 가운데 여야는 민생-경제 법안...
# 3  새수장 앞세워 대대적 전략 수정\n엔비디아 검증 탈락설 즉각 반박\n삼성전자가 인공...
# 4  22대 국회 이것만큼은\n안철수 국민의힘 분당갑 당선인\n\n최근 복원된 승정원일기...
# 5  부자 정의 명확지 않은채\n무조건 ‘돈 더 많이 내라’\n세금 초과 부담 최소화를\...
# 6  "단 10건이라도 처리해야…국회의 당연한 책무"\n더불어민주당이 26일 국민의힘을 ...
# 7  선도지구 선정 앞둔 1기 신도시\n소형-대형 면적따라 유불리 갈려\n재건축 주민동의...
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024\n\n맥베이 KKR CIO가...
# 9  정부, 성장사다리 대책 추진\n승계 관련 세제 포함도 검토\n부동산 등 자산 이전은...

# %%
save_directory = os.path.join(os.getcwd(), "data")

if not os.path.exists(save_directory):
    os.makedirs(save_directory)

file_path = os.path.join(save_directory, "news_data.csv")
test_df.to_csv(file_path, index=False, encoding='utf-8-sig') ## csv 저장
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4     os.makedirs(save_directory)
#       6 file_path = os.path.join(save_directory, "news_data.csv")
# ----> 7 test_df.to_csv(file_path, index=False, encoding='utf-8-sig') ## csv 저장
#
# NameError: name 'test_df' is not defined

# %% [markdown]
# ## 데이터 적재

# %%
# save_directory = os.path.join(os.getcwd(), "data")
# file_path = os.path.join(save_directory, "news_data.csv")

# final_df = pd.read_csv("/Users/badro97/Desktop/AI_Design_demo/data/news_data.csv", encoding='utf-8-sig')
test_df = test_df[['search','title','article','pub_date']]
test_df.columns = ['검색어', '제목', '내용', '발행일']
test_df
# Out:
#    검색어                                              제목  \
# 0   AI                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1   AI                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2   AI               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3   AI                            위기의 삼성 반도체…초격차 변화 예고
# 4   AI          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5  부동산                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6  부동산                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7  부동산  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8  부동산         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9  부동산                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                                   내용                  발행일
# 0  초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI\nTV조선 뉴스\nPlay...  2024-05-26 19:19:00
# 1  [서울=뉴시스]인텔 비전 2024에서 팻 겔싱어 인텔 CEO가 인텔 가우디 3 가속...  2024-05-26 19:17:00
# 2   ⓒ News1\n21대 국회 임기 만료가 3일 남은 가운데 여야는 민생-경제 법안...  2024-05-26 19:12:00
# 3  새수장 앞세워 대대적 전략 수정\n엔비디아 검증 탈락설 즉각 반박\n삼성전자가 인공...  2024-05-26 19:11:00
# 4  22대 국회 이것만큼은\n안철수 국민의힘 분당갑 당선인\n\n최근 복원된 승정원일기...  2024-05-26 19:10:00
# 5  부자 정의 명확지 않은채\n무조건 ‘돈 더 많이 내라’\n세금 초과 부담 최소화를\...  2024-05-26 19:15:00
# 6  "단 10건이라도 처리해야…국회의 당연한 책무"\n더불어민주당이 26일 국민의힘을 ...  2024-05-26 19:06:00
# 7  선도지구 선정 앞둔 1기 신도시\n소형-대형 면적따라 유불리 갈려\n재건축 주민동의...  2024-05-26 19:04:00
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024\n\n맥베이 KKR CIO가...  2024-05-26 19:02:00
# 9  정부, 성장사다리 대책 추진\n승계 관련 세제 포함도 검토\n부동산 등 자산 이전은...  2024-05-26 19:01:00

# %%
import uuid

## 아이디 컬럼 추가
test_df['아이디'] = [str(uuid.uuid4()) for _ in range(len(test_df))]
test_df['요약'] = ''

# %%
test_df
# Out:
#    검색어                                              제목  \
# 0   AI                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1   AI                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2   AI               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3   AI                            위기의 삼성 반도체…초격차 변화 예고
# 4   AI          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5  부동산                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6  부동산                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7  부동산  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8  부동산         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9  부동산                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                                   내용                  발행일  \
# 0  초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI\nTV조선 뉴스\nPlay...  2024-05-26 19:19:00
# 1  [서울=뉴시스]인텔 비전 2024에서 팻 겔싱어 인텔 CEO가 인텔 가우디 3 가속...  2024-05-26 19:17:00
# 2   ⓒ News1\n21대 국회 임기 만료가 3일 남은 가운데 여야는 민생-경제 법안...  2024-05-26 19:12:00
# 3  새수장 앞세워 대대적 전략 수정\n엔비디아 검증 탈락설 즉각 반박\n삼성전자가 인공...  2024-05-26 19:11:00
# 4  22대 국회 이것만큼은\n안철수 국민의힘 분당갑 당선인\n\n최근 복원된 승정원일기...  2024-05-26 19:10:00
# 5  부자 정의 명확지 않은채\n무조건 ‘돈 더 많이 내라’\n세금 초과 부담 최소화를\...  2024-05-26 19:15:00
# 6  "단 10건이라도 처리해야…국회의 당연한 책무"\n더불어민주당이 26일 국민의힘을 ...  2024-05-26 19:06:00
# 7  선도지구 선정 앞둔 1기 신도시\n소형-대형 면적따라 유불리 갈려\n재건축 주민동의...  2024-05-26 19:04:00
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024\n\n맥베이 KKR CIO가...  2024-05-26 19:02:00
# 9  정부, 성장사다리 대책 추진\n승계 관련 세제 포함도 검토\n부동산 등 자산 이전은...  2024-05-26 19:01:00
#
#                                     아이디 요약
# 0  26b32242-93f2-4472-9784-9b3b3cb622f7
# 1  e4ad7804-79ca-44fd-8a63-4774ced95fa4
# 2  b7ecb4cb-0ab5-4f4b-ad29-ff31319b78eb
# 3  163ca46d-824e-4a65-b2b0-37839e2c6a62
# 4  87e855e2-6083-4180-bada-de21d9e2e01f
# 5  169fe9a4-735a-40de-90ba-4b20edad015c
# 6  ae8fc34d-fa53-41af-b3ab-5eb0332daa8f
# 7  11b84e04-2a62-4155-b7e3-3b40686dd721
# 8  cb98f4c8-76db-4d7d-a0e5-41ed164ddf94
# 9  ff863af0-9d01-4454-a0ff-72db790fb697

# %%
import snowflake.connector
from snowflake.connector.pandas_tools import pd_writer
from snowflake.connector.pandas_tools import write_pandas

# Snowflake 연결
snow_conn = snowflake.connector.connect(
    user=os.getenv('user'),
    password=os.getenv('password'),
    account=os.getenv('account'),
    role=os.getenv('role'),
    warehouse=os.getenv('warehouse'),
    database=os.getenv('database'),
    schema=os.getenv('schema')
)
snowCur = snow_conn.cursor()

write_pandas(snow_conn, test_df, 'NAVER_NEWS', auto_create_table=True, overwrite=True)

snowCur.execute("ALTER TABLE NEWS.CRAWLING_DATA.NAVER_NEWS SET COMMENT='네이버뉴스 크롤링 데이터'")

# %% [markdown]
# ## 뉴스 요약 및 중복제거

# %%
from openai import OpenAI
import snowflake.connector
from snowflake.connector.pandas_tools import pd_writer
from snowflake.connector.pandas_tools import write_pandas
import os
import pandas as pd

def summary_api():
    # db 접근
    ## 접속 인자
    snow_conn = snowflake.connector.connect(
        user=os.getenv('user'),
        password=os.getenv('password'),
        account=os.getenv('account'),
        role=os.getenv('role'),
        warehouse=os.getenv('warehouse'),
        database=os.getenv('database'),
        schema=os.getenv('schema')
    )
    snowCur = snow_conn.cursor()

    ## query 세팅(수정)
    query = '''Select "검색어", "아이디", "제목", "내용", "발행일", "요약"
    From NEWS.CRAWLING_DATA.NAVER_NEWS;'''

    ## query 조회
    snowCur.execute(query) 
    data = snowCur.fetchall()
    columns = [desc[0] for desc in snowCur.description]
    df = pd.DataFrame(data, columns=columns)
    
    # 요약
    ## openai 접속정보
    openai_api_key = st.secrets.OPENAI_API_KEY
    client = OpenAI(api_key=openai_api_key)

    ## init prompt
    prompt = '''
    뉴스를 읽고 mask를 채워줘.
    
    [뉴스]
    {content}
    
    [요약문]
    서론 : mask
    본론 : mask
    결론 : mask
    '''

    ## summary
    ids = df["아이디"].to_list()
    df["요약"] = "" 
    summary_to_id = {}
    ## (수정)
    for id in ids:
        messages = []
        messages.append({"role":"system", "content": "당신은 주어진 틀에 맞춰 뉴스를 요약해주는 챗봇입니다. user가 뉴스를 입력하면 mask에 정보를 입력해주세요."})

        content = df[df["아이디"] == id]["내용"].values[0]
        input_prompt = prompt.format(content=content)
        
        messages.append({"role":"user", "content": input_prompt})
        response = client.chat.completions.create(model="gpt-3.5-turbo", messages=messages)
        response.choices[0]
        msg = response.choices[0].message.content
    
        # 문자열을 줄바꿈 문자로 분리
        sections = msg.split('\n')
        
        # 각 섹션에서 내용만 추출
        try:
            extracted_contents = ' '.join([section.split(' : ')[1] for section in sections if section])
        except:
            extracted_contents = msg
        df.loc[df['아이디'] == id, '요약'] = extracted_contents

    
    print(len(df), "개의 요약문을 입력하였습니다.")
    return df

# %%
df = summary_api()
df
# Out:
# 10 개의 요약문을 입력하였습니다.
#    검색어                                   아이디  \
# 0   AI  3051d6ff-0543-4ab9-9bb4-38d867a1103b
# 1   AI  06bb9c60-3523-48f1-87fc-9c9ac30ceb56
# 2   AI  61edc23e-0d38-4918-b3ec-0495647f513f
# 3   AI  1332141a-e6fd-44e5-86b5-79cb380ee1ef
# 4   AI  5c83dcee-3f0c-4a8c-9f3b-76db16137aed
# 5  부동산  0e846b71-07ca-46c6-9d36-be66bd748a7a
# 6  부동산  dd7dd271-ceba-4692-8cdc-5b754c5eb4be
# 7  부동산  6ff4b86c-e4d7-401b-bb5e-563e2259d89e
# 8  부동산  a2412621-a7f1-4e61-8bea-a974b765b5d2
# 9  부동산  0d141636-7cf3-4e61-afe6-495c79389f75
#
#                                                제목  \
# 0                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3                            위기의 삼성 반도체…초격차 변화 예고
# 4          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                                   내용                  발행일  \
# 0  초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI\nTV조선 뉴스\nPlay...  2024-05-26 19:19:00
# 1  [서울=뉴시스]인텔 비전 2024에서 팻 겔싱어 인텔 CEO가 인텔 가우디 3 가속...  2024-05-26 19:17:00
# 2   ⓒ News1\n21대 국회 임기 만료가 3일 남은 가운데 여야는 민생-경제 법안...  2024-05-26 19:12:00
# 3  새수장 앞세워 대대적 전략 수정\n엔비디아 검증 탈락설 즉각 반박\n삼성전자가 인공...  2024-05-26 19:11:00
# 4  22대 국회 이것만큼은\n안철수 국민의힘 분당갑 당선인\n\n최근 복원된 승정원일기...  2024-05-26 19:10:00
# 5  부자 정의 명확지 않은채\n무조건 ‘돈 더 많이 내라’\n세금 초과 부담 최소화를\...  2024-05-26 19:15:00
# 6  "단 10건이라도 처리해야…국회의 당연한 책무"\n더불어민주당이 26일 국민의힘을 ...  2024-05-26 19:06:00
# 7  선도지구 선정 앞둔 1기 신도시\n소형-대형 면적따라 유불리 갈려\n재건축 주민동의...  2024-05-26 19:04:00
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024\n\n맥베이 KKR CIO가...  2024-05-26 19:02:00
# 9  정부, 성장사다리 대책 추진\n승계 관련 세제 포함도 검토\n부동산 등 자산 이전은...  2024-05-26 19:01:00
#
#                                                   요약
# 0  AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있는데, 이번에는 웹툰 그리기...
# 1  인텔 최고경영자의 한국 방문이 무산되면서 업계의 관심이 쏠리고 있다. 펫 겔싱어 C...
# 2  21대 국회 임기 만료가 3일 남아 여야가 민생-경제 법안 처리를 두고 갈등을 겪고...
# 3  서론: 삼성전자가 SK하이닉스, TSMC와의 격차를 좁히지 못하면서 전략 수정에 나...
# 4  안철수 국민의힘 의원이 22대 국회에서 AI 관련 법안을 발의할 예정이라고 밝혔다....
# 5  부자 정의의 명확성에 대한 의문을 제기하며 부자증세에 대한 현재의 접근 방식의 한계...
# 6  더불어민주당이 국회의힘을 향해 21대 국회 임기 내 민생법안 처리를 위한 법제사법위...
# 7  경기 분당에서 1기 신도시 선도지구 선정 및 재건축 추진에 대한 긴장감이 높아지고 ...
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024에서는 한국과 미국 경제에 관...
# 9  정부가 중소·중견기업의 '가업 승계' 부담을 줄이기 위해 상속·증여 시 공제를 확대...

# %%
df['요약'].loc[1]
# Out:
# "인텔 최고경영자의 한국 방문이 무산되면서 업계의 관심이 쏠리고 있다. 펫 겔싱어 CEO는 인텔코리아가 진행하는 'AI 서밋'에 참석할 예정이었으나 방한을 최종 결정하지 않았다. 일정 변경에 대한 추측으로는 삼성전자 DS부문장 교체와의 연관성이 제기되고 있다.  인텔코리아 관계자는 대만 일정은 변경 없이 진행될 예정이며, 한국 행사 불참은 내부 사정 때문이라고 밝혔다."

# %%
df['내용'] = df['내용'].apply(lambda x: x.replace('\n','.').replace('..', '.'))
df['요약'] = df['요약'].apply(lambda x: x.replace('\n','.').replace('..', '.'))
df
# Out:
#    검색어                                   아이디  \
# 0   AI  3051d6ff-0543-4ab9-9bb4-38d867a1103b
# 1   AI  06bb9c60-3523-48f1-87fc-9c9ac30ceb56
# 2   AI  61edc23e-0d38-4918-b3ec-0495647f513f
# 3   AI  1332141a-e6fd-44e5-86b5-79cb380ee1ef
# 4   AI  5c83dcee-3f0c-4a8c-9f3b-76db16137aed
# 5  부동산  0e846b71-07ca-46c6-9d36-be66bd748a7a
# 6  부동산  dd7dd271-ceba-4692-8cdc-5b754c5eb4be
# 7  부동산  6ff4b86c-e4d7-401b-bb5e-563e2259d89e
# 8  부동산  a2412621-a7f1-4e61-8bea-a974b765b5d2
# 9  부동산  0d141636-7cf3-4e61-afe6-495c79389f75
#
#                                                제목  \
# 0                 초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI
# 1                        팻 겔싱어 인텔 CEO, 6월 방한 '무산'
# 2               고준위 특별법-모성3법 등 민생-경제 법안 줄폐기 ‘빨간불’
# 3                            위기의 삼성 반도체…초격차 변화 예고
# 4          안철수 "인문학 AI로 古書 복원하면 K콘텐츠 만들 소재 쏟아질 것"
# 5                         [안종범의 정책진단] 부자증세라는 포퓰리즘
# 6                 민주 "'구하라법' 등 민생법안 처리 위해 법사위 열자"
# 7  정부 평가기준 내놓자 바로 채점표 등장... 분당·평촌 "결과 지켜보자" 거래...
# 8         美 연착륙 할까, M7 넘을 종목은…'투자의 심장' 뉴욕서 해답 찾는다
# 9                 중소·중견기업 '가업 승계' 위해 상속·증여 공제 늘리나
#
#                                                   내용                  발행일  \
# 0  초상화를 '이현세 만화풍'으로 쓱쓱…만화까지 파고든 AI.TV조선 뉴스.Play.1...  2024-05-26 19:19:00
# 1  [서울=뉴시스]인텔 비전 2024에서 팻 겔싱어 인텔 CEO가 인텔 가우디 3 가속...  2024-05-26 19:17:00
# 2   ⓒ News1.21대 국회 임기 만료가 3일 남은 가운데 여야는 민생-경제 법안 ...  2024-05-26 19:12:00
# 3  새수장 앞세워 대대적 전략 수정.엔비디아 검증 탈락설 즉각 반박.삼성전자가 인공지능...  2024-05-26 19:11:00
# 4  22대 국회 이것만큼은.안철수 국민의힘 분당갑 당선인.최근 복원된 승정원일기 복수극...  2024-05-26 19:10:00
# 5  부자 정의 명확지 않은채.무조건 ‘돈 더 많이 내라’.세금 초과 부담 최소화를.안종...  2024-05-26 19:15:00
# 6  "단 10건이라도 처리해야…국회의 당연한 책무".더불어민주당이 26일 국민의힘을 향...  2024-05-26 19:06:00
# 7  선도지구 선정 앞둔 1기 신도시.소형-대형 면적따라 유불리 갈려.재건축 주민동의서 ...  2024-05-26 19:04:00
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024.맥베이 KKR CIO가 기조...  2024-05-26 19:02:00
# 9  정부, 성장사다리 대책 추진.승계 관련 세제 포함도 검토.부동산 등 자산 이전은 차...  2024-05-26 19:01:00
#
#                                                   요약
# 0  AI가 산업 현장 뿐 아니라 문화 예술에서도 활용되고 있는데, 이번에는 웹툰 그리기...
# 1  인텔 최고경영자의 한국 방문이 무산되면서 업계의 관심이 쏠리고 있다. 펫 겔싱어 C...
# 2  21대 국회 임기 만료가 3일 남아 여야가 민생-경제 법안 처리를 두고 갈등을 겪고...
# 3  서론: 삼성전자가 SK하이닉스, TSMC와의 격차를 좁히지 못하면서 전략 수정에 나...
# 4  안철수 국민의힘 의원이 22대 국회에서 AI 관련 법안을 발의할 예정이라고 밝혔다....
# 5  부자 정의의 명확성에 대한 의문을 제기하며 부자증세에 대한 현재의 접근 방식의 한계...
# 6  더불어민주당이 국회의힘을 향해 21대 국회 임기 내 민생법안 처리를 위한 법제사법위...
# 7  경기 분당에서 1기 신도시 선도지구 선정 및 재건축 추진에 대한 긴장감이 높아지고 ...
# 8  6월 3~5일 한경 글로벌마켓 콘퍼런스 NYC 2024에서는 한국과 미국 경제에 관...
# 9  정부가 중소·중견기업의 '가업 승계' 부담을 줄이기 위해 상속·증여 시 공제를 확대...

# %%
write_pandas(snow_conn, df, 'NAVER_NEWS', auto_create_table=False, overwrite=True)
# Out:
# (True,
#  1,
#  10,
#  [('vznlmhqsxz/file0.txt', 'LOADED', 10, 10, 1, 0, None, None, None, None)])

# %%
snow_conn.close()
